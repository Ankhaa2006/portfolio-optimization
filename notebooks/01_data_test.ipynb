# %%
import yfinance as yf
import pandas as pd

print("Testing data pull...")
spy = yf.download('SPY', start='2020-01-01', end='2024-01-01')
print(f"\nSPY data shape: {spy.shape}")
spy.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Testing data pull...
#
# SPY data shape: (1006, 5)
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2020-01-02  297.699005  297.717350  295.554718  296.480254  59151200
# 2020-01-03  295.444763  296.571900  294.244329  294.299309  77709700
# 2020-01-06  296.571899  296.654369  293.566200  293.685332  55653900
# 2020-01-07  295.737915  296.480167  295.288878  296.003640  40496400
# 2020-01-08  297.314178  298.532930  295.683052  295.930460  68296000
